# %% [markdown]
# # Library needed

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Excel file needed
# https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction

# %%
heart_df = pd.read_csv('heart_train.csv')

# %%
heart_df.describe(include= 'all')
# Out:
#                Age  Sex ChestPainType   RestingBP  Cholesterol   FastingBS  \
# count   918.000000  918           918  918.000000   918.000000  918.000000
# unique         NaN    2             4         NaN          NaN         NaN
# top            NaN    M           ASY         NaN          NaN         NaN
# freq           NaN  725           496         NaN          NaN         NaN
# mean     53.510893  NaN           NaN  132.396514   198.799564    0.233115
# std       9.432617  NaN           NaN   18.514154   109.384145    0.423046
# min      28.000000  NaN           NaN    0.000000     0.000000    0.000000
# 25%      47.000000  NaN           NaN  120.000000   173.250000    0.000000
# 50%      54.000000  NaN           NaN  130.000000   223.000000    0.000000
# 75%      60.000000  NaN           NaN  140.000000   267.000000    0.000000
# max      77.000000  NaN           NaN  200.000000   603.000000    1.000000
#
#        RestingECG       MaxHR ExerciseAngina     Oldpeak ST_Slope  \
# count         918  918.000000            918  918.000000      918
# unique          3         NaN              2         NaN        3
# top        Normal         NaN              N         NaN     Flat
# freq          552         NaN            547         NaN      460
# mean          NaN  136.809368            NaN    0.887364      NaN
# std           NaN   25.460334            NaN    1.066570      NaN
# min           NaN   60.000000            NaN   -2.600000      NaN
# 25%           NaN  120.000000            NaN    0.000000      NaN
# 50%           NaN  138.000000            NaN    0.600000      NaN
# 75%           NaN  156.000000            NaN    1.500000      NaN
# max           NaN  202.000000            NaN    6.200000      NaN
#
#         HeartDisease
# count     918.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.553377
# std         0.497414
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# Attribute Information
# - Age: age of the patient [years]
# - Sex: sex of the patient [M: Male, F: Female]
# - ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
# - RestingBP: resting blood pressure [mm Hg]
# - Cholesterol: serum cholesterol [mm/dl]
# - FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
# - RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
# - MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
# - ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
# - Oldpeak: oldpeak = ST [Numeric value measured in depression]
# - ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
# - HeartDisease: output class [1: heart disease, 0: Normal]

# %% [markdown]
# # Clean Dataset

# %%
# Create a copy of the Dataset
Heart_df_clean = heart_df.copy()

# Rename "#" to "ID" of Pokemon
Heart_df_clean.rename(columns = {'#': 'ID'}, inplace = True)

# Convert all Variable Names to UPPERCASE
Heart_df_clean.columns = Heart_df_clean.columns.str.upper()

# Remove all spaces and dots from Variable Names
Heart_df_clean.columns = Heart_df_clean.columns.str.replace(".","")
Heart_df_clean.columns = Heart_df_clean.columns.str.replace(" ","_")

# Print the Variable Information to check
Heart_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AGE             918 non-null    int64
#  1   SEX             918 non-null    object
#  2   CHESTPAINTYPE   918 non-null    object
#  3   RESTINGBP       918 non-null    int64
#  4   CHOLESTEROL     918 non-null    int64
#  5   FASTINGBS       918 non-null    int64
#  6   RESTINGECG      918 non-null    object
#  7   MAXHR           918 non-null    int64
#  8   EXERCISEANGINA  918 non-null    object
#  9   OLDPEAK         918 non-null    float64
#  10  ST_SLOPE        918 non-null    object
#  11  HEARTDISEASE    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB
# C:\Users\LCP\AppData\Local\Temp\ipykernel_6888\1996328438.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Heart_df_clean.columns = Heart_df_clean.columns.str.replace(".","")

# %%
# Numeric
heart_AGE = pd.DataFrame(Heart_df_clean['AGE'])
heart_RBP = pd.DataFrame(Heart_df_clean['RESTINGBP'])
heart_CLS = pd.DataFrame(Heart_df_clean['CHOLESTEROL'])
heart_MAXHR = pd.DataFrame(Heart_df_clean['MAXHR'])
heart_HD = pd.DataFrame(Heart_df_clean['HEARTDISEASE'])

#catogrical
heart_SEX = pd.DataFrame(Heart_df_clean['SEX'])
heart_EA = pd.DataFrame(Heart_df_clean['EXERCISEANGINA'])
heart_CPT = pd.DataFrame(Heart_df_clean['CHESTPAINTYPE'])

# %% [markdown]
# # Reconfig type

# %%
heartC_HD = heart_HD
heartC_HD.replace(to_replace=[1,0],value = ['Y','N'],inplace = True )

# %%
heartC_HD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HEARTDISEASE  918 non-null    object
# dtypes: object(1)
# memory usage: 7.3+ KB

# %% [markdown]
# # Visualisation

# %%
f1,ax1= plt.subplots(4,1,figsize =(24,24))
sb.boxplot(data = heart_AGE, orient ='h',ax=ax1[0])
sb.boxplot(data = heart_RBP, orient ='h',ax=ax1[1])
sb.boxplot(data = heart_CLS, orient ='h',ax=ax1[2])
sb.boxplot(data = heart_MAXHR, orient ='h',ax=ax1[3])
# Out:
# <AxesSubplot:>

# %%
sb.countplot(x='HEARTDISEASE',data =heartC_HD,orient='h')
# Out:
# <AxesSubplot:xlabel='HEARTDISEASE', ylabel='count'>

# %%
sb.countplot(y ='SEX',data = heart_SEX,orient ='v')
# Out:
# <AxesSubplot:xlabel='count', ylabel='SEX'>

# %%
sb.countplot( y ='EXERCISEANGINA',data = heart_EA,orient='v')
# Out:
# <AxesSubplot:xlabel='count', ylabel='EXERCISEANGINA'>

# %%
sb.catplot(x='CHESTPAINTYPE',data = heart_CPT,kind='count')

# %%
f3 = plt.figure(figsize =(24,24))
sb.heatmap(Heart_df_clean.corr()[['HEARTDISEASE']], vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
test1 = pd.concat([heartC_HD,heart_SEX],axis=1).reindex(heartC_HD.index)
test2 = pd.concat([heartC_HD,heart_EA],axis=1).reindex(heartC_HD.index)
test3 = pd.concat([heartC_HD,heart_CPT],axis=1).reindex(heartC_HD.index)

# %%
f4,ax2 =plt.subplots(1,2,figsize= (24,24))
sb.countplot(data =test1,x='HEARTDISEASE',hue='SEX',ax=ax2[0])
sb.countplot(data =test2,x='HEARTDISEASE',hue='EXERCISEANGINA',ax=ax2[1])
# Out:
# <AxesSubplot:xlabel='HEARTDISEASE', ylabel='count'>

# %%
sb.countplot(data =test3,y='CHESTPAINTYPE',hue='HEARTDISEASE',orient='v')
# Out:
# <AxesSubplot:xlabel='count', ylabel='CHESTPAINTYPE'>

# %% [markdown]
# # Machine Learning(model)

# %%
from sklearn.tree import plot_tree
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
#-------------[model1,2]----------------------
from sklearn.tree import DecisionTreeClassifier
#-------------[model3,4]----------------------
from sklearn.ensemble import RandomForestClassifier
#-------------[model5,6]------------------------
from tensorflow import keras
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import StandardScaler

# %%
def neural_net_results(X, y):

    y = keras.utils.to_categorical(y, 2)

    X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3,
                                                      random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    model = keras.Sequential([
        keras.layers.Flatten(input_dim=X_train.shape[1]),
        keras.layers.Dropout(0.1),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
              batch_size=10, epochs=70,
              validation_data=(X_val, y_val),
              verbose=0)

    score = np.round(model.evaluate(X_val, y_val, verbose=0)[1], 3)
    print(f'Neural Network score    ========>>> {score}')
    history_plot(history)
    return score
def history_plot(history):

    f11 = plt.figure(figsize=(12, 8))
    plt.plot(history.history['accuracy'], label="Train loss")
    plt.plot(history.history['val_accuracy'], label="Test loss")
    plt.legend()


def plot_nn_model(model):
    plot_model(model, show_shapes=True)
    
models_results = np.zeros(4)

# %%
models_results[-1] = neural_net_results(heart_RBP,heart_df['HeartDisease'])
# Out:
# Neural Network score    ========>>> 0.493

# %% [markdown]
# # increase epochs

# %%
def neural_net_results(X, y):

    y = keras.utils.to_categorical(y, 2)

    X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3,
                                                      random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    model = keras.Sequential([
        keras.layers.Flatten(input_dim=X_train.shape[1]),
        keras.layers.Dropout(0.1),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
              batch_size=10, epochs=200,
              validation_data=(X_val, y_val),
              verbose=0)

    score = np.round(model.evaluate(X_val, y_val, verbose=0)[1], 3)
    print(f'Neural Network score    ========>>> {score}')
    history_plot(history)
    return score
def history_plot(history):

    f11 = plt.figure(figsize=(12, 8))
    plt.plot(history.history['accuracy'], label="Train loss")
    plt.plot(history.history['val_accuracy'], label="Test loss")
    plt.legend()


def plot_nn_model(model):
    plot_model(model, show_shapes=True)
    
models_results = np.zeros(4)

# %%
models_results[-1] = neural_net_results(heart_RBP,heart_df['HeartDisease'])
# Out:
# Neural Network score    ========>>> 0.493

# %% [markdown]
# # increase of batch size

# %%
def neural_net_results(X, y):

    y = keras.utils.to_categorical(y, 2)

    X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3,
                                                      random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    model = keras.Sequential([
        keras.layers.Flatten(input_dim=X_train.shape[1]),
        keras.layers.Dropout(0.1),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
              batch_size=30, epochs=70,
              validation_data=(X_val, y_val),
              verbose=1)

    score = np.round(model.evaluate(X_val, y_val, verbose=0)[1], 3)
    print(f'Neural Network score    ========>>> {score}')
    history_plot(history)
    return score
def history_plot(history):

    f11 = plt.figure(figsize=(12, 8))
    plt.plot(history.history['accuracy'], label="Train loss")
    plt.plot(history.history['val_accuracy'], label="Test loss")
    plt.legend()


def plot_nn_model(model):
    plot_model(model, show_shapes=True)
    
models_results = np.zeros(4)

# %%
models_results[-1] = neural_net_results(heart_RBP,heart_df['HeartDisease'])
# Out:
# Epoch 1/70
# 22/22 [==============================] - 1s 18ms/step - loss: 0.6977 - accuracy: 0.5234 - val_loss: 0.6795 - val_accuracy: 0.5109
# Epoch 2/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6951 - accuracy: 0.5514 - val_loss: 0.6774 - val_accuracy: 0.4964
# Epoch 3/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6880 - accuracy: 0.5545 - val_loss: 0.6762 - val_accuracy: 0.5181
# Epoch 4/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6942 - accuracy: 0.5218 - val_loss: 0.6789 - val_accuracy: 0.4928
# Epoch 5/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6946 - accuracy: 0.5498 - val_loss: 0.6789 - val_accuracy: 0.4964
# Epoch 6/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6908 - accuracy: 0.5561 - val_loss: 0.6785 - val_accuracy: 0.4928
# Epoch 7/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6846 - accuracy: 0.5607 - val_loss: 0.6802 - val_accuracy: 0.4891
# Epoch 8/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6885 - accuracy: 0.5452 - val_loss: 0.6794 - val_accuracy: 0.4964
# Epoch 9/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6836 - accuracy: 0.5498 - val_loss: 0.6797 - val_accuracy: 0.4964
# Epoch 10/70
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6872 - accuracy: 0.5343 - val_loss: 0.6783 - val_accuracy: 0.5109
# Epoch 11/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6799 - accuracy: 0.5530 - val_loss: 0.6778 - val_accuracy: 0.4964
# Epoch 12/70
# 22/22 [==============================] - 0s 9ms/step - loss: 0.6857 - accuracy: 0.5483 - val_loss: 0.6792 - val_accuracy: 0.4891
# Epoch 13/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6857 - accuracy: 0.5498 - val_loss: 0.6827 - val_accuracy: 0.4891
# Epoch 14/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6862 - accuracy: 0.5421 - val_loss: 0.6802 - val_accuracy: 0.4964
# Epoch 15/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6844 - accuracy: 0.5592 - val_loss: 0.6805 - val_accuracy: 0.4964
# Epoch 16/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6882 - accuracy: 0.5467 - val_loss: 0.6781 - val_accuracy: 0.4964
# Epoch 17/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6841 - accuracy: 0.5405 - val_loss: 0.6789 - val_accuracy: 0.4964
# Epoch 18/70
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6872 - accuracy: 0.5763 - val_loss: 0.6810 - val_accuracy: 0.4891
# Epoch 19/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6861 - accuracy: 0.5530 - val_loss: 0.6826 - val_accuracy: 0.4928
# Epoch 20/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6847 - accuracy: 0.5576 - val_loss: 0.6829 - val_accuracy: 0.4928
# Epoch 21/70
# 22/22 [==============================] - 0s 9ms/step - loss: 0.6881 - accuracy: 0.5514 - val_loss: 0.6819 - val_accuracy: 0.4891
# Epoch 22/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6814 - accuracy: 0.5763 - val_loss: 0.6815 - val_accuracy: 0.4928
# Epoch 23/70
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6874 - accuracy: 0.5343 - val_loss: 0.6812 - val_accuracy: 0.4891
# Epoch 24/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6786 - accuracy: 0.5779 - val_loss: 0.6839 - val_accuracy: 0.4928
# Epoch 25/70
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6888 - accuracy: 0.5436 - val_loss: 0.6845 - val_accuracy: 0.4928
# Epoch 26/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6829 - accuracy: 0.5452 - val_loss: 0.6824 - val_accuracy: 0.4891
# Epoch 27/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6814 - accuracy: 0.5717 - val_loss: 0.6809 - val_accuracy: 0.4891
# Epoch 28/70
# 22/22 [==============================] - 0s 9ms/step - loss: 0.6855 - accuracy: 0.5483 - val_loss: 0.6832 - val_accuracy: 0.4928
# Epoch 29/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6814 - accuracy: 0.5639 - val_loss: 0.6836 - val_accuracy: 0.4928
# Epoch 30/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6820 - accuracy: 0.5483 - val_loss: 0.6816 - val_accuracy: 0.4891
# Epoch 31/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6810 - accuracy: 0.5670 - val_loss: 0.6814 - val_accuracy: 0.4891
# Epoch 32/70
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6838 - accuracy: 0.5343 - val_loss: 0.6815 - val_accuracy: 0.4928
# Epoch 33/70
# 22/22 [==============================] - 0s 10ms/step - loss: 0.6777 - accuracy: 0.5576 - val_loss: 0.6833 - val_accuracy: 0.4928
# Epoch 34/70
# 22/22 [==============================] - 0s 10ms/step - loss: 0.6814 - accuracy: 0.5545 - val_loss: 0.6840 - val_accuracy: 0.4928
# Epoch 35/70
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6842 - accuracy: 0.5498 - val_loss: 0.6824 - val_accuracy: 0.4891
# Epoch 36/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6824 - accuracy: 0.5530 - val_loss: 0.6828 - val_accuracy: 0.4891
# Epoch 37/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6875 - accuracy: 0.5498 - val_loss: 0.6816 - val_accuracy: 0.4891
# Epoch 38/70
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6868 - accuracy: 0.5545 - val_loss: 0.6821 - val_accuracy: 0.4891
# Epoch 39/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6796 - accuracy: 0.5794 - val_loss: 0.6824 - val_accuracy: 0.4891
# Epoch 40/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6873 - accuracy: 0.5576 - val_loss: 0.6824 - val_accuracy: 0.4928
# Epoch 41/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6791 - accuracy: 0.5654 - val_loss: 0.6844 - val_accuracy: 0.4928
# Epoch 42/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6847 - accuracy: 0.5748 - val_loss: 0.6846 - val_accuracy: 0.4928
# Epoch 43/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6860 - accuracy: 0.5514 - val_loss: 0.6851 - val_accuracy: 0.4928
# Epoch 44/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6814 - accuracy: 0.5576 - val_loss: 0.6850 - val_accuracy: 0.4891
# Epoch 45/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6800 - accuracy: 0.5576 - val_loss: 0.6798 - val_accuracy: 0.4964
# Epoch 46/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6878 - accuracy: 0.5389 - val_loss: 0.6795 - val_accuracy: 0.4964
# Epoch 47/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6867 - accuracy: 0.5436 - val_loss: 0.6835 - val_accuracy: 0.4891
# Epoch 48/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6837 - accuracy: 0.5592 - val_loss: 0.6858 - val_accuracy: 0.4928
# Epoch 49/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6801 - accuracy: 0.5467 - val_loss: 0.6832 - val_accuracy: 0.4891
# Epoch 50/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6822 - accuracy: 0.5421 - val_loss: 0.6818 - val_accuracy: 0.4891
# Epoch 51/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6806 - accuracy: 0.5530 - val_loss: 0.6802 - val_accuracy: 0.4891
# Epoch 52/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6814 - accuracy: 0.5561 - val_loss: 0.6826 - val_accuracy: 0.4928
# Epoch 53/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6849 - accuracy: 0.5405 - val_loss: 0.6823 - val_accuracy: 0.4928
# Epoch 54/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6815 - accuracy: 0.5654 - val_loss: 0.6801 - val_accuracy: 0.4891
# Epoch 55/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6840 - accuracy: 0.5421 - val_loss: 0.6814 - val_accuracy: 0.4928
# Epoch 56/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6828 - accuracy: 0.5280 - val_loss: 0.6807 - val_accuracy: 0.4928
# Epoch 57/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6860 - accuracy: 0.5421 - val_loss: 0.6783 - val_accuracy: 0.4964
# Epoch 58/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6811 - accuracy: 0.5748 - val_loss: 0.6790 - val_accuracy: 0.4964
# Epoch 59/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6836 - accuracy: 0.5327 - val_loss: 0.6790 - val_accuracy: 0.4964
# Epoch 60/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6769 - accuracy: 0.5498 - val_loss: 0.6793 - val_accuracy: 0.4964
# Epoch 61/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6817 - accuracy: 0.5545 - val_loss: 0.6804 - val_accuracy: 0.4928
# Epoch 62/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6814 - accuracy: 0.5452 - val_loss: 0.6824 - val_accuracy: 0.5326
# Epoch 63/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6829 - accuracy: 0.5717 - val_loss: 0.6828 - val_accuracy: 0.5326
# Epoch 64/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6857 - accuracy: 0.5576 - val_loss: 0.6818 - val_accuracy: 0.5326
# Epoch 65/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6861 - accuracy: 0.5545 - val_loss: 0.6800 - val_accuracy: 0.5326
# Epoch 66/70
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6848 - accuracy: 0.5576 - val_loss: 0.6804 - val_accuracy: 0.5326
# Epoch 67/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6837 - accuracy: 0.5436 - val_loss: 0.6819 - val_accuracy: 0.5326
# Epoch 68/70
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6848 - accuracy: 0.5654 - val_loss: 0.6822 - val_accuracy: 0.5326
# Epoch 69/70
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6819 - accuracy: 0.5561 - val_loss: 0.6815 - val_accuracy: 0.5326
# Epoch 70/70
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6794 - accuracy: 0.5607 - val_loss: 0.6807 - val_accuracy: 0.4928
# Neural Network score    ========>>> 0.493

# %% [markdown]
# # Increase number of hidden layer

# %%
def neural_net_results(X, y):

    y = keras.utils.to_categorical(y, 2)

    X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3,
                                                      random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    model = keras.Sequential([
        keras.layers.Flatten(input_dim=X_train.shape[1]),
        keras.layers.Dropout(0.1),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
              batch_size=10, epochs=70,
              validation_data=(X_val, y_val),
              verbose=1)

    score = np.round(model.evaluate(X_val, y_val, verbose=0)[1], 3)
    print(f'Neural Network score    ========>>> {score}')
    history_plot(history)
    return score
def history_plot(history):

    f11 = plt.figure(figsize=(12, 8))
    plt.plot(history.history['accuracy'], label="Train loss")
    plt.plot(history.history['val_accuracy'], label="Test loss")
    plt.legend()


def plot_nn_model(model):
    plot_model(model, show_shapes=True)
    
models_results = np.zeros(4)

# %%
models_results[-1] = neural_net_results(heart_RBP,heart_df['HeartDisease'])
# Out:
# Epoch 1/70
# 65/65 [==============================] - 1s 8ms/step - loss: 0.6973 - accuracy: 0.5125 - val_loss: 0.6811 - val_accuracy: 0.4964
# Epoch 2/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6888 - accuracy: 0.5670 - val_loss: 0.6802 - val_accuracy: 0.4964
# Epoch 3/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6798 - accuracy: 0.5763 - val_loss: 0.6877 - val_accuracy: 0.4928
# Epoch 4/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6862 - accuracy: 0.5654 - val_loss: 0.6837 - val_accuracy: 0.4928
# Epoch 5/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6813 - accuracy: 0.5670 - val_loss: 0.6792 - val_accuracy: 0.4928
# Epoch 6/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6875 - accuracy: 0.5405 - val_loss: 0.6862 - val_accuracy: 0.4928
# Epoch 7/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6833 - accuracy: 0.5748 - val_loss: 0.6816 - val_accuracy: 0.4891
# Epoch 8/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6873 - accuracy: 0.5545 - val_loss: 0.6850 - val_accuracy: 0.4928
# Epoch 9/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6924 - accuracy: 0.5327 - val_loss: 0.6797 - val_accuracy: 0.4964
# Epoch 10/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6882 - accuracy: 0.5234 - val_loss: 0.6815 - val_accuracy: 0.4964
# Epoch 11/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6845 - accuracy: 0.5530 - val_loss: 0.6790 - val_accuracy: 0.4964
# Epoch 12/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.5530 - val_loss: 0.6819 - val_accuracy: 0.4891
# Epoch 13/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6834 - accuracy: 0.5467 - val_loss: 0.6842 - val_accuracy: 0.4928
# Epoch 14/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.5280 - val_loss: 0.6793 - val_accuracy: 0.4891
# Epoch 15/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6861 - accuracy: 0.5483 - val_loss: 0.6813 - val_accuracy: 0.4891
# Epoch 16/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6809 - accuracy: 0.5779 - val_loss: 0.6805 - val_accuracy: 0.4964
# Epoch 17/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6855 - accuracy: 0.5592 - val_loss: 0.6834 - val_accuracy: 0.4891
# Epoch 18/70
# 65/65 [==============================] - 0s 7ms/step - loss: 0.6863 - accuracy: 0.5514 - val_loss: 0.6844 - val_accuracy: 0.4891
# Epoch 19/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6833 - accuracy: 0.5670 - val_loss: 0.6819 - val_accuracy: 0.4964
# Epoch 20/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6773 - accuracy: 0.5623 - val_loss: 0.6815 - val_accuracy: 0.4928
# Epoch 21/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6867 - accuracy: 0.5452 - val_loss: 0.6833 - val_accuracy: 0.4928
# Epoch 22/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6836 - accuracy: 0.5421 - val_loss: 0.6842 - val_accuracy: 0.4891
# Epoch 23/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6768 - accuracy: 0.5576 - val_loss: 0.6825 - val_accuracy: 0.4964
# Epoch 24/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6870 - accuracy: 0.5452 - val_loss: 0.6873 - val_accuracy: 0.4928
# Epoch 25/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6805 - accuracy: 0.5467 - val_loss: 0.6782 - val_accuracy: 0.4964
# Epoch 26/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6781 - accuracy: 0.5763 - val_loss: 0.6814 - val_accuracy: 0.4891
# Epoch 27/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6838 - accuracy: 0.5327 - val_loss: 0.6775 - val_accuracy: 0.4891
# Epoch 28/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6793 - accuracy: 0.5249 - val_loss: 0.6737 - val_accuracy: 0.5507
# Epoch 29/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6852 - accuracy: 0.5530 - val_loss: 0.6792 - val_accuracy: 0.4928
# Epoch 30/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6851 - accuracy: 0.5685 - val_loss: 0.6811 - val_accuracy: 0.4928
# Epoch 31/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6827 - accuracy: 0.5374 - val_loss: 0.6787 - val_accuracy: 0.4891
# Epoch 32/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6858 - accuracy: 0.5779 - val_loss: 0.6825 - val_accuracy: 0.4891
# Epoch 33/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6795 - accuracy: 0.5670 - val_loss: 0.6856 - val_accuracy: 0.4964
# Epoch 34/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6843 - accuracy: 0.5530 - val_loss: 0.6832 - val_accuracy: 0.4928
# Epoch 35/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6893 - accuracy: 0.5530 - val_loss: 0.6831 - val_accuracy: 0.4964
# Epoch 36/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6825 - accuracy: 0.5748 - val_loss: 0.6843 - val_accuracy: 0.4964
# Epoch 37/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6827 - accuracy: 0.5607 - val_loss: 0.6857 - val_accuracy: 0.4964
# Epoch 38/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6868 - accuracy: 0.5452 - val_loss: 0.6810 - val_accuracy: 0.4964
# Epoch 39/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6822 - accuracy: 0.5561 - val_loss: 0.6800 - val_accuracy: 0.4891
# Epoch 40/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6838 - accuracy: 0.5561 - val_loss: 0.6819 - val_accuracy: 0.4891
# Epoch 41/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6809 - accuracy: 0.5545 - val_loss: 0.6844 - val_accuracy: 0.4928
# Epoch 42/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6845 - accuracy: 0.5374 - val_loss: 0.6824 - val_accuracy: 0.4964
# Epoch 43/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6811 - accuracy: 0.5685 - val_loss: 0.6810 - val_accuracy: 0.4964
# Epoch 44/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6812 - accuracy: 0.5654 - val_loss: 0.6838 - val_accuracy: 0.4891
# Epoch 45/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6818 - accuracy: 0.5436 - val_loss: 0.6823 - val_accuracy: 0.4964
# Epoch 46/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6847 - accuracy: 0.5701 - val_loss: 0.6862 - val_accuracy: 0.4891
# Epoch 47/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6824 - accuracy: 0.5623 - val_loss: 0.6838 - val_accuracy: 0.4964
# Epoch 48/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6850 - accuracy: 0.5639 - val_loss: 0.6857 - val_accuracy: 0.4891
# Epoch 49/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6844 - accuracy: 0.5576 - val_loss: 0.6845 - val_accuracy: 0.4891
# Epoch 50/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6800 - accuracy: 0.5514 - val_loss: 0.6843 - val_accuracy: 0.4891
# Epoch 51/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6810 - accuracy: 0.5685 - val_loss: 0.6843 - val_accuracy: 0.4928
# Epoch 52/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6746 - accuracy: 0.5607 - val_loss: 0.6832 - val_accuracy: 0.4928
# Epoch 53/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6819 - accuracy: 0.5670 - val_loss: 0.6836 - val_accuracy: 0.4891
# Epoch 54/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6841 - accuracy: 0.5467 - val_loss: 0.6848 - val_accuracy: 0.4928
# Epoch 55/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6834 - accuracy: 0.5732 - val_loss: 0.6843 - val_accuracy: 0.4891
# Epoch 56/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6809 - accuracy: 0.5545 - val_loss: 0.6839 - val_accuracy: 0.4891
# Epoch 57/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6804 - accuracy: 0.5545 - val_loss: 0.6853 - val_accuracy: 0.5326
# Epoch 58/70
# 65/65 [==============================] - 1s 8ms/step - loss: 0.6839 - accuracy: 0.5592 - val_loss: 0.6811 - val_accuracy: 0.4855
# Epoch 59/70
# 65/65 [==============================] - 0s 7ms/step - loss: 0.6832 - accuracy: 0.5545 - val_loss: 0.6827 - val_accuracy: 0.4891
# Epoch 60/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6820 - accuracy: 0.5483 - val_loss: 0.6852 - val_accuracy: 0.4928
# Epoch 61/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6823 - accuracy: 0.5452 - val_loss: 0.6848 - val_accuracy: 0.4928
# Epoch 62/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6847 - accuracy: 0.5405 - val_loss: 0.6844 - val_accuracy: 0.4928
# Epoch 63/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6807 - accuracy: 0.5592 - val_loss: 0.6873 - val_accuracy: 0.5326
# Epoch 64/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.5717 - val_loss: 0.6847 - val_accuracy: 0.4891
# Epoch 65/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6785 - accuracy: 0.5779 - val_loss: 0.6858 - val_accuracy: 0.4928
# Epoch 66/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6804 - accuracy: 0.5670 - val_loss: 0.6870 - val_accuracy: 0.4891
# Epoch 67/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6776 - accuracy: 0.5654 - val_loss: 0.6850 - val_accuracy: 0.4964
# Epoch 68/70
# 65/65 [==============================] - 0s 5ms/step - loss: 0.6796 - accuracy: 0.5483 - val_loss: 0.6844 - val_accuracy: 0.4891
# Epoch 69/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6800 - accuracy: 0.5343 - val_loss: 0.6853 - val_accuracy: 0.4928
# Epoch 70/70
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6791 - accuracy: 0.5545 - val_loss: 0.6841 - val_accuracy: 0.4855
# Neural Network score    ========>>> 0.486
