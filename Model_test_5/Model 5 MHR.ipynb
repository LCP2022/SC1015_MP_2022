# %% [markdown]
# # Library needed

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Excel file needed
# https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction

# %%
heart_df = pd.read_csv('heart_train.csv')

# %%
heart_df.describe(include= 'all')
# Out:
#                Age  Sex ChestPainType   RestingBP  Cholesterol   FastingBS  \
# count   918.000000  918           918  918.000000   918.000000  918.000000
# unique         NaN    2             4         NaN          NaN         NaN
# top            NaN    M           ASY         NaN          NaN         NaN
# freq           NaN  725           496         NaN          NaN         NaN
# mean     53.510893  NaN           NaN  132.396514   198.799564    0.233115
# std       9.432617  NaN           NaN   18.514154   109.384145    0.423046
# min      28.000000  NaN           NaN    0.000000     0.000000    0.000000
# 25%      47.000000  NaN           NaN  120.000000   173.250000    0.000000
# 50%      54.000000  NaN           NaN  130.000000   223.000000    0.000000
# 75%      60.000000  NaN           NaN  140.000000   267.000000    0.000000
# max      77.000000  NaN           NaN  200.000000   603.000000    1.000000
#
#        RestingECG       MaxHR ExerciseAngina     Oldpeak ST_Slope  \
# count         918  918.000000            918  918.000000      918
# unique          3         NaN              2         NaN        3
# top        Normal         NaN              N         NaN     Flat
# freq          552         NaN            547         NaN      460
# mean          NaN  136.809368            NaN    0.887364      NaN
# std           NaN   25.460334            NaN    1.066570      NaN
# min           NaN   60.000000            NaN   -2.600000      NaN
# 25%           NaN  120.000000            NaN    0.000000      NaN
# 50%           NaN  138.000000            NaN    0.600000      NaN
# 75%           NaN  156.000000            NaN    1.500000      NaN
# max           NaN  202.000000            NaN    6.200000      NaN
#
#         HeartDisease
# count     918.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.553377
# std         0.497414
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# Attribute Information
# - Age: age of the patient [years]
# - Sex: sex of the patient [M: Male, F: Female]
# - ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
# - RestingBP: resting blood pressure [mm Hg]
# - Cholesterol: serum cholesterol [mm/dl]
# - FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
# - RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
# - MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
# - ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
# - Oldpeak: oldpeak = ST [Numeric value measured in depression]
# - ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
# - HeartDisease: output class [1: heart disease, 0: Normal]

# %% [markdown]
# # Clean Dataset

# %%
# Create a copy of the Dataset
Heart_df_clean = heart_df.copy()

# Rename "#" to "ID" of Pokemon
Heart_df_clean.rename(columns = {'#': 'ID'}, inplace = True)

# Convert all Variable Names to UPPERCASE
Heart_df_clean.columns = Heart_df_clean.columns.str.upper()

# Remove all spaces and dots from Variable Names
Heart_df_clean.columns = Heart_df_clean.columns.str.replace(".","")
Heart_df_clean.columns = Heart_df_clean.columns.str.replace(" ","_")

# Print the Variable Information to check
Heart_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AGE             918 non-null    int64
#  1   SEX             918 non-null    object
#  2   CHESTPAINTYPE   918 non-null    object
#  3   RESTINGBP       918 non-null    int64
#  4   CHOLESTEROL     918 non-null    int64
#  5   FASTINGBS       918 non-null    int64
#  6   RESTINGECG      918 non-null    object
#  7   MAXHR           918 non-null    int64
#  8   EXERCISEANGINA  918 non-null    object
#  9   OLDPEAK         918 non-null    float64
#  10  ST_SLOPE        918 non-null    object
#  11  HEARTDISEASE    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB
# C:\Users\LCP\AppData\Local\Temp\ipykernel_16892\1996328438.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Heart_df_clean.columns = Heart_df_clean.columns.str.replace(".","")

# %%
# Numeric
heart_AGE = pd.DataFrame(Heart_df_clean['AGE'])
heart_RBP = pd.DataFrame(Heart_df_clean['RESTINGBP'])
heart_CLS = pd.DataFrame(Heart_df_clean['CHOLESTEROL'])
heart_MAXHR = pd.DataFrame(Heart_df_clean['MAXHR'])
heart_HD = pd.DataFrame(Heart_df_clean['HEARTDISEASE'])

#catogrical
heart_SEX = pd.DataFrame(Heart_df_clean['SEX'])
heart_EA = pd.DataFrame(Heart_df_clean['EXERCISEANGINA'])
heart_CPT = pd.DataFrame(Heart_df_clean['CHESTPAINTYPE'])

# %% [markdown]
# # Reconfig type

# %%
heartC_HD = heart_HD
heartC_HD.replace(to_replace=[1,0],value = ['Y','N'],inplace = True )

# %%
heartC_HD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HEARTDISEASE  918 non-null    object
# dtypes: object(1)
# memory usage: 7.3+ KB

# %% [markdown]
# # Visualisation

# %%
f1,ax1= plt.subplots(4,1,figsize =(24,24))
sb.boxplot(data = heart_AGE, orient ='h',ax=ax1[0])
sb.boxplot(data = heart_RBP, orient ='h',ax=ax1[1])
sb.boxplot(data = heart_CLS, orient ='h',ax=ax1[2])
sb.boxplot(data = heart_MAXHR, orient ='h',ax=ax1[3])
# Out:
# <AxesSubplot:>

# %%
sb.countplot(x='HEARTDISEASE',data =heartC_HD,orient='h')
# Out:
# <AxesSubplot:xlabel='HEARTDISEASE', ylabel='count'>

# %%
sb.countplot(y ='SEX',data = heart_SEX,orient ='v')
# Out:
# <AxesSubplot:xlabel='count', ylabel='SEX'>

# %%
sb.countplot( y ='EXERCISEANGINA',data = heart_EA,orient='v')
# Out:
# <AxesSubplot:xlabel='count', ylabel='EXERCISEANGINA'>

# %%
sb.catplot(x='CHESTPAINTYPE',data = heart_CPT,kind='count')

# %%
f3 = plt.figure(figsize =(24,24))
sb.heatmap(Heart_df_clean.corr()[['HEARTDISEASE']], vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
test1 = pd.concat([heartC_HD,heart_SEX],axis=1).reindex(heartC_HD.index)
test2 = pd.concat([heartC_HD,heart_EA],axis=1).reindex(heartC_HD.index)
test3 = pd.concat([heartC_HD,heart_CPT],axis=1).reindex(heartC_HD.index)

# %%
f4,ax2 =plt.subplots(1,2,figsize= (24,24))
sb.countplot(data =test1,x='HEARTDISEASE',hue='SEX',ax=ax2[0])
sb.countplot(data =test2,x='HEARTDISEASE',hue='EXERCISEANGINA',ax=ax2[1])
# Out:
# <AxesSubplot:xlabel='HEARTDISEASE', ylabel='count'>

# %%
sb.countplot(data =test3,y='CHESTPAINTYPE',hue='HEARTDISEASE',orient='v')
# Out:
# <AxesSubplot:xlabel='count', ylabel='CHESTPAINTYPE'>

# %% [markdown]
# # Machine Learning(model)

# %%
from sklearn.tree import plot_tree
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
#-------------[model1,2]----------------------
from sklearn.tree import DecisionTreeClassifier
#-------------[model3,4]----------------------
from sklearn.ensemble import RandomForestClassifier
#-------------[model5,6]------------------------
from tensorflow import keras
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import StandardScaler

# %%
def neural_net_results(X, y):

    y = keras.utils.to_categorical(y, 2)

    X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3,
                                                      random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    model = keras.Sequential([
        keras.layers.Flatten(input_dim=X_train.shape[1]),
        keras.layers.Dropout(0.1),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
              batch_size=10, epochs=70,
              validation_data=(X_val, y_val),
              verbose=0)

    score = np.round(model.evaluate(X_val, y_val, verbose=0)[1], 3)
    print(f'Neural Network score    ========>>> {score}')
    history_plot(history)
    return score
def history_plot(history):

    f11 = plt.figure(figsize=(12, 8))
    plt.plot(history.history['accuracy'], label="Train loss")
    plt.plot(history.history['val_accuracy'], label="Test loss")
    plt.legend()


def plot_nn_model(model):
    plot_model(model, show_shapes=True)
    
models_results = np.zeros(4)

# %%
models_results[-1] = neural_net_results(heart_MAXHR,heart_df['HeartDisease'])
# Out:
# Neural Network score    ========>>> 0.696

# %% [markdown]
# # increase of epochs

# %%
def neural_net_results(X, y):

    y = keras.utils.to_categorical(y, 2)

    X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3,
                                                      random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    model = keras.Sequential([
        keras.layers.Flatten(input_dim=X_train.shape[1]),
        keras.layers.Dropout(0.1),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
              batch_size=10, epochs=200,
              validation_data=(X_val, y_val),
              verbose=0)

    score = np.round(model.evaluate(X_val, y_val, verbose=0)[1], 3)
    print(f'Neural Network score    ========>>> {score}')
    history_plot(history)
    return score
def history_plot(history):

    f11 = plt.figure(figsize=(12, 8))
    plt.plot(history.history['accuracy'], label="Train loss")
    plt.plot(history.history['val_accuracy'], label="Test loss")
    plt.legend()


def plot_nn_model(model):
    plot_model(model, show_shapes=True)
    
models_results = np.zeros(4)

# %%
models_results[-1] = neural_net_results(heart_MAXHR,heart_df['HeartDisease'])
# Out:
# Neural Network score    ========>>> 0.696

# %% [markdown]
# # increase of batch size

# %%
def neural_net_results(X, y):

    y = keras.utils.to_categorical(y, 2)

    X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3,
                                                      random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    model = keras.Sequential([
        keras.layers.Flatten(input_dim=X_train.shape[1]),
        keras.layers.Dropout(0.1),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
              batch_size=30, epochs=70,
              validation_data=(X_val, y_val),
              verbose=1)

    score = np.round(model.evaluate(X_val, y_val, verbose=0)[1], 3)
    print(f'Neural Network score    ========>>> {score}')
    history_plot(history)
    return score
def history_plot(history):

    f11 = plt.figure(figsize=(12, 8))
    plt.plot(history.history['accuracy'], label="Train loss")
    plt.plot(history.history['val_accuracy'], label="Test loss")
    plt.legend()


def plot_nn_model(model):
    plot_model(model, show_shapes=True)
    
models_results = np.zeros(4)

# %%
models_results[-1] = neural_net_results(heart_MAXHR,heart_df['HeartDisease'])
# Out:
# Epoch 1/70
# 22/22 [==============================] - 1s 14ms/step - loss: 0.7030 - accuracy: 0.5218 - val_loss: 0.6483 - val_accuracy: 0.6957
# Epoch 2/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6597 - accuracy: 0.6075 - val_loss: 0.6126 - val_accuracy: 0.6775
# Epoch 3/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6321 - accuracy: 0.6386 - val_loss: 0.5987 - val_accuracy: 0.6920
# Epoch 4/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6167 - accuracy: 0.6558 - val_loss: 0.5934 - val_accuracy: 0.6920
# Epoch 5/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6262 - accuracy: 0.6558 - val_loss: 0.5936 - val_accuracy: 0.6920
# Epoch 6/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6326 - accuracy: 0.6402 - val_loss: 0.5936 - val_accuracy: 0.6775
# Epoch 7/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6066 - accuracy: 0.6604 - val_loss: 0.5919 - val_accuracy: 0.6775
# Epoch 8/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6270 - accuracy: 0.6511 - val_loss: 0.5914 - val_accuracy: 0.6812
# Epoch 9/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6237 - accuracy: 0.6558 - val_loss: 0.5913 - val_accuracy: 0.6812
# Epoch 10/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6211 - accuracy: 0.6604 - val_loss: 0.5936 - val_accuracy: 0.6775
# Epoch 11/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6294 - accuracy: 0.6511 - val_loss: 0.5914 - val_accuracy: 0.6993
# Epoch 12/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6142 - accuracy: 0.6573 - val_loss: 0.5929 - val_accuracy: 0.6993
# Epoch 13/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6284 - accuracy: 0.6449 - val_loss: 0.5926 - val_accuracy: 0.6993
# Epoch 14/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6252 - accuracy: 0.6526 - val_loss: 0.5910 - val_accuracy: 0.6957
# Epoch 15/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6102 - accuracy: 0.6526 - val_loss: 0.5909 - val_accuracy: 0.6993
# Epoch 16/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6248 - accuracy: 0.6464 - val_loss: 0.5919 - val_accuracy: 0.6812
# Epoch 17/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6183 - accuracy: 0.6433 - val_loss: 0.5918 - val_accuracy: 0.6993
# Epoch 18/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6210 - accuracy: 0.6246 - val_loss: 0.5911 - val_accuracy: 0.6993
# Epoch 19/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6231 - accuracy: 0.6449 - val_loss: 0.5911 - val_accuracy: 0.6812
# Epoch 20/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6232 - accuracy: 0.6542 - val_loss: 0.5903 - val_accuracy: 0.6993
# Epoch 21/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6168 - accuracy: 0.6495 - val_loss: 0.5912 - val_accuracy: 0.6993
# Epoch 22/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6190 - accuracy: 0.6464 - val_loss: 0.5929 - val_accuracy: 0.6775
# Epoch 23/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6236 - accuracy: 0.6480 - val_loss: 0.5916 - val_accuracy: 0.6775
# Epoch 24/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6210 - accuracy: 0.6589 - val_loss: 0.5909 - val_accuracy: 0.6775
# Epoch 25/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6320 - accuracy: 0.6386 - val_loss: 0.5910 - val_accuracy: 0.6775
# Epoch 26/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6191 - accuracy: 0.6558 - val_loss: 0.5910 - val_accuracy: 0.6775
# Epoch 27/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6227 - accuracy: 0.6511 - val_loss: 0.5908 - val_accuracy: 0.6957
# Epoch 28/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6235 - accuracy: 0.6495 - val_loss: 0.5930 - val_accuracy: 0.6812
# Epoch 29/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6157 - accuracy: 0.6402 - val_loss: 0.5914 - val_accuracy: 0.6920
# Epoch 30/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6160 - accuracy: 0.6558 - val_loss: 0.5904 - val_accuracy: 0.6957
# Epoch 31/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6241 - accuracy: 0.6464 - val_loss: 0.5906 - val_accuracy: 0.6957
# Epoch 32/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6229 - accuracy: 0.6604 - val_loss: 0.5903 - val_accuracy: 0.6920
# Epoch 33/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6140 - accuracy: 0.6340 - val_loss: 0.5917 - val_accuracy: 0.6957
# Epoch 34/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6133 - accuracy: 0.6573 - val_loss: 0.5889 - val_accuracy: 0.6957
# Epoch 35/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6153 - accuracy: 0.6636 - val_loss: 0.5886 - val_accuracy: 0.6920
# Epoch 36/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6062 - accuracy: 0.6542 - val_loss: 0.5876 - val_accuracy: 0.6957
# Epoch 37/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6044 - accuracy: 0.6604 - val_loss: 0.5895 - val_accuracy: 0.6957
# Epoch 38/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6175 - accuracy: 0.6511 - val_loss: 0.5877 - val_accuracy: 0.6957
# Epoch 39/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6103 - accuracy: 0.6511 - val_loss: 0.5886 - val_accuracy: 0.6957
# Epoch 40/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6225 - accuracy: 0.6386 - val_loss: 0.5894 - val_accuracy: 0.6957
# Epoch 41/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6176 - accuracy: 0.6449 - val_loss: 0.5897 - val_accuracy: 0.6993
# Epoch 42/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6264 - accuracy: 0.6449 - val_loss: 0.5921 - val_accuracy: 0.6993
# Epoch 43/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6157 - accuracy: 0.6464 - val_loss: 0.5919 - val_accuracy: 0.6993
# Epoch 44/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6175 - accuracy: 0.6495 - val_loss: 0.5904 - val_accuracy: 0.6920
# Epoch 45/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6250 - accuracy: 0.6324 - val_loss: 0.5905 - val_accuracy: 0.6957
# Epoch 46/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6322 - accuracy: 0.6464 - val_loss: 0.5914 - val_accuracy: 0.7029
# Epoch 47/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6190 - accuracy: 0.6386 - val_loss: 0.5912 - val_accuracy: 0.6812
# Epoch 48/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6203 - accuracy: 0.6604 - val_loss: 0.5913 - val_accuracy: 0.6775
# Epoch 49/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6159 - accuracy: 0.6495 - val_loss: 0.5908 - val_accuracy: 0.6775
# Epoch 50/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6199 - accuracy: 0.6495 - val_loss: 0.5901 - val_accuracy: 0.6775
# Epoch 51/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6226 - accuracy: 0.6542 - val_loss: 0.5917 - val_accuracy: 0.6957
# Epoch 52/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6167 - accuracy: 0.6464 - val_loss: 0.5937 - val_accuracy: 0.6957
# Epoch 53/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6185 - accuracy: 0.6573 - val_loss: 0.5940 - val_accuracy: 0.6957
# Epoch 54/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6180 - accuracy: 0.6526 - val_loss: 0.5921 - val_accuracy: 0.6957
# Epoch 55/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6235 - accuracy: 0.6371 - val_loss: 0.5917 - val_accuracy: 0.6920
# Epoch 56/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6296 - accuracy: 0.6464 - val_loss: 0.5929 - val_accuracy: 0.6775
# Epoch 57/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6156 - accuracy: 0.6667 - val_loss: 0.5909 - val_accuracy: 0.6920
# Epoch 58/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6299 - accuracy: 0.6355 - val_loss: 0.5918 - val_accuracy: 0.6775
# Epoch 59/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6072 - accuracy: 0.6542 - val_loss: 0.5898 - val_accuracy: 0.6920
# Epoch 60/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6156 - accuracy: 0.6511 - val_loss: 0.5910 - val_accuracy: 0.6957
# Epoch 61/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6333 - accuracy: 0.6308 - val_loss: 0.5919 - val_accuracy: 0.6957
# Epoch 62/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6208 - accuracy: 0.6464 - val_loss: 0.5914 - val_accuracy: 0.6920
# Epoch 63/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6228 - accuracy: 0.6386 - val_loss: 0.5921 - val_accuracy: 0.6920
# Epoch 64/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6160 - accuracy: 0.6402 - val_loss: 0.5911 - val_accuracy: 0.6812
# Epoch 65/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6267 - accuracy: 0.6340 - val_loss: 0.5930 - val_accuracy: 0.6920
# Epoch 66/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6227 - accuracy: 0.6495 - val_loss: 0.5922 - val_accuracy: 0.6957
# Epoch 67/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6109 - accuracy: 0.6449 - val_loss: 0.5902 - val_accuracy: 0.6957
# Epoch 68/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6118 - accuracy: 0.6542 - val_loss: 0.5903 - val_accuracy: 0.6957
# Epoch 69/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6225 - accuracy: 0.6417 - val_loss: 0.5882 - val_accuracy: 0.6920
# Epoch 70/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6225 - accuracy: 0.6573 - val_loss: 0.5917 - val_accuracy: 0.6920
# Neural Network score    ========>>> 0.692

# %% [markdown]
# # increase of hidden layer

# %%
def neural_net_results(X, y):

    y = keras.utils.to_categorical(y, 2)

    X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3,
                                                      random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    model = keras.Sequential([
        keras.layers.Flatten(input_dim=X_train.shape[1]),
        keras.layers.Dropout(0.1),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
              batch_size=10, epochs=70,
              validation_data=(X_val, y_val),
              verbose=1)

    score = np.round(model.evaluate(X_val, y_val, verbose=0)[1], 3)
    print(f'Neural Network score    ========>>> {score}')
    history_plot(history)
    return score
def history_plot(history):

    f11 = plt.figure(figsize=(12, 8))
    plt.plot(history.history['accuracy'], label="Train loss")
    plt.plot(history.history['val_accuracy'], label="Test loss")
    plt.legend()


def plot_nn_model(model):
    plot_model(model, show_shapes=True)
    
models_results = np.zeros(4)

# %%
models_results[-1] = neural_net_results(heart_MAXHR,heart_df['HeartDisease'])
# Out:
# Epoch 1/70
# 65/65 [==============================] - 1s 6ms/step - loss: 0.6409 - accuracy: 0.6277 - val_loss: 0.5947 - val_accuracy: 0.6775
# Epoch 2/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6305 - accuracy: 0.6511 - val_loss: 0.5899 - val_accuracy: 0.6812
# Epoch 3/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6281 - accuracy: 0.6277 - val_loss: 0.5939 - val_accuracy: 0.6775
# Epoch 4/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6248 - accuracy: 0.6589 - val_loss: 0.5935 - val_accuracy: 0.6775
# Epoch 5/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6171 - accuracy: 0.6371 - val_loss: 0.5898 - val_accuracy: 0.6993
# Epoch 6/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6225 - accuracy: 0.6495 - val_loss: 0.5900 - val_accuracy: 0.6993
# Epoch 7/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6205 - accuracy: 0.6636 - val_loss: 0.5914 - val_accuracy: 0.6957
# Epoch 8/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6192 - accuracy: 0.6340 - val_loss: 0.5877 - val_accuracy: 0.6957
# Epoch 9/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6157 - accuracy: 0.6542 - val_loss: 0.5915 - val_accuracy: 0.6957
# Epoch 10/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6220 - accuracy: 0.6480 - val_loss: 0.5888 - val_accuracy: 0.7065
# Epoch 11/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6247 - accuracy: 0.6480 - val_loss: 0.5881 - val_accuracy: 0.6957
# Epoch 12/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6274 - accuracy: 0.6542 - val_loss: 0.5898 - val_accuracy: 0.7029
# Epoch 13/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6240 - accuracy: 0.6417 - val_loss: 0.5901 - val_accuracy: 0.7065
# Epoch 14/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6230 - accuracy: 0.6355 - val_loss: 0.5890 - val_accuracy: 0.7065
# Epoch 15/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6139 - accuracy: 0.6667 - val_loss: 0.5889 - val_accuracy: 0.6957
# Epoch 16/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6135 - accuracy: 0.6417 - val_loss: 0.5864 - val_accuracy: 0.7065
# Epoch 17/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6169 - accuracy: 0.6464 - val_loss: 0.5884 - val_accuracy: 0.6957
# Epoch 18/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6171 - accuracy: 0.6464 - val_loss: 0.5895 - val_accuracy: 0.7029
# Epoch 19/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6188 - accuracy: 0.6620 - val_loss: 0.5922 - val_accuracy: 0.6957
# Epoch 20/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6242 - accuracy: 0.6402 - val_loss: 0.5910 - val_accuracy: 0.7029
# Epoch 21/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6151 - accuracy: 0.6620 - val_loss: 0.5900 - val_accuracy: 0.7065
# Epoch 22/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6232 - accuracy: 0.6371 - val_loss: 0.5916 - val_accuracy: 0.6920
# Epoch 23/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6119 - accuracy: 0.6573 - val_loss: 0.5895 - val_accuracy: 0.6957
# Epoch 24/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6245 - accuracy: 0.6371 - val_loss: 0.5887 - val_accuracy: 0.6957
# Epoch 25/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6261 - accuracy: 0.6495 - val_loss: 0.5893 - val_accuracy: 0.7065
# Epoch 26/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6186 - accuracy: 0.6386 - val_loss: 0.5880 - val_accuracy: 0.7065
# Epoch 27/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6159 - accuracy: 0.6371 - val_loss: 0.5868 - val_accuracy: 0.6957
# Epoch 28/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6157 - accuracy: 0.6433 - val_loss: 0.5902 - val_accuracy: 0.6957
# Epoch 29/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6193 - accuracy: 0.6464 - val_loss: 0.5885 - val_accuracy: 0.7029
# Epoch 30/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6163 - accuracy: 0.6573 - val_loss: 0.5871 - val_accuracy: 0.7029
# Epoch 31/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6121 - accuracy: 0.6480 - val_loss: 0.5861 - val_accuracy: 0.7029
# Epoch 32/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6254 - accuracy: 0.6199 - val_loss: 0.5899 - val_accuracy: 0.7029
# Epoch 33/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6037 - accuracy: 0.6246 - val_loss: 0.5867 - val_accuracy: 0.6920
# Epoch 34/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6140 - accuracy: 0.6340 - val_loss: 0.5897 - val_accuracy: 0.6812
# Epoch 35/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6133 - accuracy: 0.6589 - val_loss: 0.5884 - val_accuracy: 0.6920
# Epoch 36/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6187 - accuracy: 0.6542 - val_loss: 0.5879 - val_accuracy: 0.6993
# Epoch 37/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6225 - accuracy: 0.6371 - val_loss: 0.5920 - val_accuracy: 0.6812
# Epoch 38/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6214 - accuracy: 0.6511 - val_loss: 0.5909 - val_accuracy: 0.6993
# Epoch 39/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6174 - accuracy: 0.6433 - val_loss: 0.5942 - val_accuracy: 0.6812
# Epoch 40/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6137 - accuracy: 0.6355 - val_loss: 0.5923 - val_accuracy: 0.6775
# Epoch 41/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6204 - accuracy: 0.6293 - val_loss: 0.5890 - val_accuracy: 0.6812
# Epoch 42/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6274 - accuracy: 0.6402 - val_loss: 0.5927 - val_accuracy: 0.6812
# Epoch 43/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6165 - accuracy: 0.6355 - val_loss: 0.5892 - val_accuracy: 0.6775
# Epoch 44/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6212 - accuracy: 0.6480 - val_loss: 0.5909 - val_accuracy: 0.6812
# Epoch 45/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6179 - accuracy: 0.6262 - val_loss: 0.5914 - val_accuracy: 0.6993
# Epoch 46/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6160 - accuracy: 0.6480 - val_loss: 0.5909 - val_accuracy: 0.6812
# Epoch 47/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6146 - accuracy: 0.6386 - val_loss: 0.5906 - val_accuracy: 0.6957
# Epoch 48/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6102 - accuracy: 0.6636 - val_loss: 0.5886 - val_accuracy: 0.6957
# Epoch 49/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6255 - accuracy: 0.6480 - val_loss: 0.5892 - val_accuracy: 0.6920
# Epoch 50/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6134 - accuracy: 0.6449 - val_loss: 0.5881 - val_accuracy: 0.6812
# Epoch 51/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6236 - accuracy: 0.6449 - val_loss: 0.5930 - val_accuracy: 0.6957
# Epoch 52/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6135 - accuracy: 0.6542 - val_loss: 0.5933 - val_accuracy: 0.6920
# Epoch 53/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6242 - accuracy: 0.6511 - val_loss: 0.5917 - val_accuracy: 0.6993
# Epoch 54/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6112 - accuracy: 0.6558 - val_loss: 0.5896 - val_accuracy: 0.6993
# Epoch 55/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6082 - accuracy: 0.6542 - val_loss: 0.5891 - val_accuracy: 0.6812
# Epoch 56/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6273 - accuracy: 0.6417 - val_loss: 0.5894 - val_accuracy: 0.6993
# Epoch 57/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6188 - accuracy: 0.6604 - val_loss: 0.5900 - val_accuracy: 0.6920
# Epoch 58/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6138 - accuracy: 0.6480 - val_loss: 0.5876 - val_accuracy: 0.6957
# Epoch 59/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6069 - accuracy: 0.6480 - val_loss: 0.5888 - val_accuracy: 0.6775
# Epoch 60/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6178 - accuracy: 0.6495 - val_loss: 0.5883 - val_accuracy: 0.6920
# Epoch 61/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6064 - accuracy: 0.6682 - val_loss: 0.5884 - val_accuracy: 0.6920
# Epoch 62/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6090 - accuracy: 0.6589 - val_loss: 0.5904 - val_accuracy: 0.6920
# Epoch 63/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6124 - accuracy: 0.6604 - val_loss: 0.5885 - val_accuracy: 0.6812
# Epoch 64/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6193 - accuracy: 0.6526 - val_loss: 0.5893 - val_accuracy: 0.6920
# Epoch 65/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6064 - accuracy: 0.6651 - val_loss: 0.5906 - val_accuracy: 0.6920
# Epoch 66/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6167 - accuracy: 0.6355 - val_loss: 0.5908 - val_accuracy: 0.6775
# Epoch 67/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6187 - accuracy: 0.6324 - val_loss: 0.5883 - val_accuracy: 0.6957
# Epoch 68/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6162 - accuracy: 0.6386 - val_loss: 0.5878 - val_accuracy: 0.6812
# Epoch 69/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6177 - accuracy: 0.6480 - val_loss: 0.5887 - val_accuracy: 0.6920
# Epoch 70/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6237 - accuracy: 0.6526 - val_loss: 0.5903 - val_accuracy: 0.6775
# Neural Network score    ========>>> 0.678
