# %% [markdown]
# # Library needed

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Excel file needed
# https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction

# %%
heart_df = pd.read_csv('heart_train.csv')

# %%
heart_df.describe(include= 'all')
# Out:
#                Age  Sex ChestPainType   RestingBP  Cholesterol   FastingBS  \
# count   918.000000  918           918  918.000000   918.000000  918.000000
# unique         NaN    2             4         NaN          NaN         NaN
# top            NaN    M           ASY         NaN          NaN         NaN
# freq           NaN  725           496         NaN          NaN         NaN
# mean     53.510893  NaN           NaN  132.396514   198.799564    0.233115
# std       9.432617  NaN           NaN   18.514154   109.384145    0.423046
# min      28.000000  NaN           NaN    0.000000     0.000000    0.000000
# 25%      47.000000  NaN           NaN  120.000000   173.250000    0.000000
# 50%      54.000000  NaN           NaN  130.000000   223.000000    0.000000
# 75%      60.000000  NaN           NaN  140.000000   267.000000    0.000000
# max      77.000000  NaN           NaN  200.000000   603.000000    1.000000
#
#        RestingECG       MaxHR ExerciseAngina     Oldpeak ST_Slope  \
# count         918  918.000000            918  918.000000      918
# unique          3         NaN              2         NaN        3
# top        Normal         NaN              N         NaN     Flat
# freq          552         NaN            547         NaN      460
# mean          NaN  136.809368            NaN    0.887364      NaN
# std           NaN   25.460334            NaN    1.066570      NaN
# min           NaN   60.000000            NaN   -2.600000      NaN
# 25%           NaN  120.000000            NaN    0.000000      NaN
# 50%           NaN  138.000000            NaN    0.600000      NaN
# 75%           NaN  156.000000            NaN    1.500000      NaN
# max           NaN  202.000000            NaN    6.200000      NaN
#
#         HeartDisease
# count     918.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.553377
# std         0.497414
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# Attribute Information
# - Age: age of the patient [years]
# - Sex: sex of the patient [M: Male, F: Female]
# - ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
# - RestingBP: resting blood pressure [mm Hg]
# - Cholesterol: serum cholesterol [mm/dl]
# - FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
# - RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
# - MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
# - ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
# - Oldpeak: oldpeak = ST [Numeric value measured in depression]
# - ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
# - HeartDisease: output class [1: heart disease, 0: Normal]

# %% [markdown]
# # Clean Dataset

# %%
# Create a copy of the Dataset
Heart_df_clean = heart_df.copy()

# Rename "#" to "ID" of Pokemon
Heart_df_clean.rename(columns = {'#': 'ID'}, inplace = True)

# Convert all Variable Names to UPPERCASE
Heart_df_clean.columns = Heart_df_clean.columns.str.upper()

# Remove all spaces and dots from Variable Names
Heart_df_clean.columns = Heart_df_clean.columns.str.replace(".","")
Heart_df_clean.columns = Heart_df_clean.columns.str.replace(" ","_")

# Print the Variable Information to check
Heart_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AGE             918 non-null    int64
#  1   SEX             918 non-null    object
#  2   CHESTPAINTYPE   918 non-null    object
#  3   RESTINGBP       918 non-null    int64
#  4   CHOLESTEROL     918 non-null    int64
#  5   FASTINGBS       918 non-null    int64
#  6   RESTINGECG      918 non-null    object
#  7   MAXHR           918 non-null    int64
#  8   EXERCISEANGINA  918 non-null    object
#  9   OLDPEAK         918 non-null    float64
#  10  ST_SLOPE        918 non-null    object
#  11  HEARTDISEASE    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB
# C:\Users\LCP\AppData\Local\Temp\ipykernel_6224\1996328438.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Heart_df_clean.columns = Heart_df_clean.columns.str.replace(".","")

# %%
# Numeric
heart_AGE = pd.DataFrame(Heart_df_clean['AGE'])
heart_RBP = pd.DataFrame(Heart_df_clean['RESTINGBP'])
heart_CLS = pd.DataFrame(Heart_df_clean['CHOLESTEROL'])
heart_MAXHR = pd.DataFrame(Heart_df_clean['MAXHR'])
heart_HD = pd.DataFrame(Heart_df_clean['HEARTDISEASE'])

#catogrical
heart_SEX = pd.DataFrame(Heart_df_clean['SEX'])
heart_EA = pd.DataFrame(Heart_df_clean['EXERCISEANGINA'])
heart_CPT = pd.DataFrame(Heart_df_clean['CHESTPAINTYPE'])

# %% [markdown]
# # Reconfig type

# %%
heartC_HD = heart_HD
heartC_HD.replace(to_replace=[1,0],value = ['Y','N'],inplace = True )

# %%
heartC_HD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HEARTDISEASE  918 non-null    object
# dtypes: object(1)
# memory usage: 7.3+ KB

# %% [markdown]
# # Visualisation

# %%
f1,ax1= plt.subplots(4,1,figsize =(24,24))
sb.boxplot(data = heart_AGE, orient ='h',ax=ax1[0])
sb.boxplot(data = heart_RBP, orient ='h',ax=ax1[1])
sb.boxplot(data = heart_CLS, orient ='h',ax=ax1[2])
sb.boxplot(data = heart_MAXHR, orient ='h',ax=ax1[3])
# Out:
# <AxesSubplot:>

# %%
sb.countplot(x='HEARTDISEASE',data =heartC_HD,orient='h')
# Out:
# <AxesSubplot:xlabel='HEARTDISEASE', ylabel='count'>

# %%
sb.countplot(y ='SEX',data = heart_SEX,orient ='v')
# Out:
# <AxesSubplot:xlabel='count', ylabel='SEX'>

# %%
sb.countplot( y ='EXERCISEANGINA',data = heart_EA,orient='v')
# Out:
# <AxesSubplot:xlabel='count', ylabel='EXERCISEANGINA'>

# %%
sb.catplot(x='CHESTPAINTYPE',data = heart_CPT,kind='count')

# %%
f3 = plt.figure(figsize =(24,24))
sb.heatmap(Heart_df_clean.corr()[['HEARTDISEASE']], vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
test1 = pd.concat([heartC_HD,heart_SEX],axis=1).reindex(heartC_HD.index)
test2 = pd.concat([heartC_HD,heart_EA],axis=1).reindex(heartC_HD.index)
test3 = pd.concat([heartC_HD,heart_CPT],axis=1).reindex(heartC_HD.index)

# %%
f4,ax2 =plt.subplots(1,2,figsize= (24,24))
sb.countplot(data =test1,x='HEARTDISEASE',hue='SEX',ax=ax2[0])
sb.countplot(data =test2,x='HEARTDISEASE',hue='EXERCISEANGINA',ax=ax2[1])
# Out:
# <AxesSubplot:xlabel='HEARTDISEASE', ylabel='count'>

# %%
sb.countplot(data =test3,y='CHESTPAINTYPE',hue='HEARTDISEASE',orient='v')
# Out:
# <AxesSubplot:xlabel='count', ylabel='CHESTPAINTYPE'>

# %% [markdown]
# # Machine Learning(model)

# %%
from sklearn.tree import plot_tree
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
#-------------[model1,2]----------------------
from sklearn.tree import DecisionTreeClassifier
#-------------[model3,4]----------------------
from sklearn.ensemble import RandomForestClassifier
#-------------[model5,6]------------------------
from tensorflow import keras
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import StandardScaler

# %%
def neural_net_results6(X, y):

    y = keras.utils.to_categorical(y, 2)

    X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3,
                                                      random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    model = keras.Sequential([
        keras.layers.Flatten(input_dim=X_train.shape[1]),
        keras.layers.Dropout(0.1),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
              batch_size=10, epochs=70,
              validation_data=(X_val, y_val),
              verbose=0)

    score = np.round(model.evaluate(X_val, y_val, verbose=0)[1], 3)
    print(f'Neural Network score    ========>>> {score}')
    history_plot6(history)
    return score
def history_plot6(history):

    f12 = plt.figure(figsize=(12, 8))
    plt.plot(history.history['accuracy'], label="Train loss")
    plt.plot(history.history['val_accuracy'], label="Test loss")
    plt.legend()


def plot_nn_model(model):
    plot_model(model, show_shapes=True)
    
models_results = np.zeros(4)

# %%
test66 = pd.DataFrame(Heart_df_clean[['AGE','CHOLESTEROL','MAXHR','RESTINGBP']])

# %%
models_results[-1] = neural_net_results6(test66,heart_df['HeartDisease'])
# Out:
# Neural Network score    ========>>> 0.717

# %% [markdown]
# # increase of epochs

# %%
def neural_net_results6(X, y):

    y = keras.utils.to_categorical(y, 2)

    X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3,
                                                      random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    model = keras.Sequential([
        keras.layers.Flatten(input_dim=X_train.shape[1]),
        keras.layers.Dropout(0.1),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
              batch_size=10, epochs=200,
              validation_data=(X_val, y_val),
              verbose=0)

    score = np.round(model.evaluate(X_val, y_val, verbose=0)[1], 3)
    print(f'Neural Network score    ========>>> {score}')
    history_plot6(history)
    return score
def history_plot6(history):

    f12 = plt.figure(figsize=(12, 8))
    plt.plot(history.history['accuracy'], label="Train loss")
    plt.plot(history.history['val_accuracy'], label="Test loss")
    plt.legend()


def plot_nn_model(model):
    plot_model(model, show_shapes=True)
    
models_results = np.zeros(4)

# %%
models_results[-1] = neural_net_results6(test66,heart_df['HeartDisease'])
# Out:
# Neural Network score    ========>>> 0.743

# %% [markdown]
# # increase batch size

# %%
def neural_net_results6(X, y):

    y = keras.utils.to_categorical(y, 2)

    X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3,
                                                      random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    model = keras.Sequential([
        keras.layers.Flatten(input_dim=X_train.shape[1]),
        keras.layers.Dropout(0.1),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
              batch_size=30, epochs=70,
              validation_data=(X_val, y_val),
              verbose=1)

    score = np.round(model.evaluate(X_val, y_val, verbose=0)[1], 3)
    print(f'Neural Network score    ========>>> {score}')
    history_plot6(history)
    return score
def history_plot6(history):

    f12 = plt.figure(figsize=(12, 8))
    plt.plot(history.history['accuracy'], label="Train loss")
    plt.plot(history.history['val_accuracy'], label="Test loss")
    plt.legend()


def plot_nn_model(model):
    plot_model(model, show_shapes=True)
    
models_results = np.zeros(4)

# %%
models_results[-1] = neural_net_results6(test66,heart_df['HeartDisease'])
# Out:
# Epoch 1/70
# 22/22 [==============================] - 1s 14ms/step - loss: 0.7034 - accuracy: 0.5374 - val_loss: 0.6288 - val_accuracy: 0.7283
# Epoch 2/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6480 - accuracy: 0.6231 - val_loss: 0.5975 - val_accuracy: 0.7283
# Epoch 3/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6397 - accuracy: 0.6573 - val_loss: 0.5836 - val_accuracy: 0.7065
# Epoch 4/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6306 - accuracy: 0.6869 - val_loss: 0.5729 - val_accuracy: 0.6993
# Epoch 5/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6088 - accuracy: 0.7056 - val_loss: 0.5703 - val_accuracy: 0.6884
# Epoch 6/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6079 - accuracy: 0.6900 - val_loss: 0.5619 - val_accuracy: 0.7029
# Epoch 7/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5823 - accuracy: 0.7150 - val_loss: 0.5640 - val_accuracy: 0.6848
# Epoch 8/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5962 - accuracy: 0.7087 - val_loss: 0.5622 - val_accuracy: 0.6884
# Epoch 9/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6012 - accuracy: 0.6807 - val_loss: 0.5572 - val_accuracy: 0.7029
# Epoch 10/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6003 - accuracy: 0.6838 - val_loss: 0.5590 - val_accuracy: 0.6848
# Epoch 11/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5948 - accuracy: 0.6978 - val_loss: 0.5577 - val_accuracy: 0.6884
# Epoch 12/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5974 - accuracy: 0.7072 - val_loss: 0.5556 - val_accuracy: 0.6920
# Epoch 13/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5945 - accuracy: 0.6916 - val_loss: 0.5549 - val_accuracy: 0.6957
# Epoch 14/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6058 - accuracy: 0.6854 - val_loss: 0.5511 - val_accuracy: 0.6993
# Epoch 15/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5955 - accuracy: 0.7196 - val_loss: 0.5504 - val_accuracy: 0.6957
# Epoch 16/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5789 - accuracy: 0.7056 - val_loss: 0.5531 - val_accuracy: 0.6884
# Epoch 17/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5960 - accuracy: 0.7025 - val_loss: 0.5530 - val_accuracy: 0.6920
# Epoch 18/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5982 - accuracy: 0.6916 - val_loss: 0.5551 - val_accuracy: 0.6848
# Epoch 19/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5729 - accuracy: 0.7009 - val_loss: 0.5581 - val_accuracy: 0.6812
# Epoch 20/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6024 - accuracy: 0.6791 - val_loss: 0.5551 - val_accuracy: 0.6848
# Epoch 21/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5809 - accuracy: 0.7134 - val_loss: 0.5540 - val_accuracy: 0.6848
# Epoch 22/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5914 - accuracy: 0.7072 - val_loss: 0.5534 - val_accuracy: 0.6884
# Epoch 23/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5755 - accuracy: 0.7165 - val_loss: 0.5528 - val_accuracy: 0.6848
# Epoch 24/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5696 - accuracy: 0.7305 - val_loss: 0.5514 - val_accuracy: 0.6848
# Epoch 25/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5918 - accuracy: 0.7056 - val_loss: 0.5529 - val_accuracy: 0.6884
# Epoch 26/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5738 - accuracy: 0.7181 - val_loss: 0.5515 - val_accuracy: 0.6920
# Epoch 27/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5786 - accuracy: 0.7134 - val_loss: 0.5516 - val_accuracy: 0.6920
# Epoch 28/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5825 - accuracy: 0.6916 - val_loss: 0.5531 - val_accuracy: 0.6812
# Epoch 29/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5765 - accuracy: 0.7196 - val_loss: 0.5511 - val_accuracy: 0.6920
# Epoch 30/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5923 - accuracy: 0.6994 - val_loss: 0.5522 - val_accuracy: 0.6920
# Epoch 31/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5855 - accuracy: 0.7056 - val_loss: 0.5546 - val_accuracy: 0.6812
# Epoch 32/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5746 - accuracy: 0.7087 - val_loss: 0.5526 - val_accuracy: 0.6848
# Epoch 33/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5779 - accuracy: 0.6963 - val_loss: 0.5528 - val_accuracy: 0.6848
# Epoch 34/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5800 - accuracy: 0.7196 - val_loss: 0.5491 - val_accuracy: 0.6957
# Epoch 35/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5933 - accuracy: 0.7056 - val_loss: 0.5459 - val_accuracy: 0.7029
# Epoch 36/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5707 - accuracy: 0.7259 - val_loss: 0.5504 - val_accuracy: 0.6957
# Epoch 37/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5802 - accuracy: 0.7118 - val_loss: 0.5509 - val_accuracy: 0.6884
# Epoch 38/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5873 - accuracy: 0.7087 - val_loss: 0.5526 - val_accuracy: 0.6848
# Epoch 39/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5751 - accuracy: 0.7103 - val_loss: 0.5493 - val_accuracy: 0.6920
# Epoch 40/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5741 - accuracy: 0.7212 - val_loss: 0.5474 - val_accuracy: 0.7065
# Epoch 41/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5776 - accuracy: 0.7072 - val_loss: 0.5529 - val_accuracy: 0.6920
# Epoch 42/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5631 - accuracy: 0.7134 - val_loss: 0.5516 - val_accuracy: 0.6884
# Epoch 43/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5771 - accuracy: 0.7181 - val_loss: 0.5469 - val_accuracy: 0.6993
# Epoch 44/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5704 - accuracy: 0.7243 - val_loss: 0.5482 - val_accuracy: 0.7029
# Epoch 45/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5773 - accuracy: 0.7134 - val_loss: 0.5485 - val_accuracy: 0.7065
# Epoch 46/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5926 - accuracy: 0.7009 - val_loss: 0.5515 - val_accuracy: 0.6884
# Epoch 47/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5773 - accuracy: 0.7212 - val_loss: 0.5528 - val_accuracy: 0.6848
# Epoch 48/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5823 - accuracy: 0.7134 - val_loss: 0.5530 - val_accuracy: 0.6884
# Epoch 49/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5675 - accuracy: 0.7103 - val_loss: 0.5479 - val_accuracy: 0.6957
# Epoch 50/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5857 - accuracy: 0.7009 - val_loss: 0.5489 - val_accuracy: 0.6993
# Epoch 51/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5561 - accuracy: 0.7274 - val_loss: 0.5488 - val_accuracy: 0.6920
# Epoch 52/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5709 - accuracy: 0.7118 - val_loss: 0.5475 - val_accuracy: 0.6957
# Epoch 53/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5917 - accuracy: 0.7025 - val_loss: 0.5480 - val_accuracy: 0.7065
# Epoch 54/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5660 - accuracy: 0.7227 - val_loss: 0.5480 - val_accuracy: 0.6993
# Epoch 55/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5784 - accuracy: 0.7134 - val_loss: 0.5512 - val_accuracy: 0.6848
# Epoch 56/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5720 - accuracy: 0.7134 - val_loss: 0.5488 - val_accuracy: 0.7065
# Epoch 57/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5841 - accuracy: 0.6900 - val_loss: 0.5482 - val_accuracy: 0.7065
# Epoch 58/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5653 - accuracy: 0.7259 - val_loss: 0.5490 - val_accuracy: 0.6993
# Epoch 59/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5623 - accuracy: 0.7150 - val_loss: 0.5462 - val_accuracy: 0.7065
# Epoch 60/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5710 - accuracy: 0.7259 - val_loss: 0.5478 - val_accuracy: 0.6848
# Epoch 61/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5637 - accuracy: 0.7383 - val_loss: 0.5453 - val_accuracy: 0.6957
# Epoch 62/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5692 - accuracy: 0.7087 - val_loss: 0.5485 - val_accuracy: 0.6884
# Epoch 63/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5629 - accuracy: 0.7243 - val_loss: 0.5455 - val_accuracy: 0.7065
# Epoch 64/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5657 - accuracy: 0.7118 - val_loss: 0.5453 - val_accuracy: 0.7065
# Epoch 65/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5849 - accuracy: 0.7025 - val_loss: 0.5471 - val_accuracy: 0.6957
# Epoch 66/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5884 - accuracy: 0.7056 - val_loss: 0.5491 - val_accuracy: 0.6920
# Epoch 67/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5744 - accuracy: 0.7243 - val_loss: 0.5482 - val_accuracy: 0.6957
# Epoch 68/70
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5649 - accuracy: 0.7336 - val_loss: 0.5513 - val_accuracy: 0.6993
# Epoch 69/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5796 - accuracy: 0.6978 - val_loss: 0.5515 - val_accuracy: 0.6957
# Epoch 70/70
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5642 - accuracy: 0.7165 - val_loss: 0.5513 - val_accuracy: 0.6993
# Neural Network score    ========>>> 0.699

# %% [markdown]
# # increase of hidden layer

# %%
def neural_net_results6(X, y):

    y = keras.utils.to_categorical(y, 2)

    X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3,
                                                      random_state=42)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    model = keras.Sequential([
        keras.layers.Flatten(input_dim=X_train.shape[1]),
        keras.layers.Dropout(0.1),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(2, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
              batch_size=10, epochs=70,
              validation_data=(X_val, y_val),
              verbose=1)

    score = np.round(model.evaluate(X_val, y_val, verbose=0)[1], 3)
    print(f'Neural Network score    ========>>> {score}')
    history_plot6(history)
    return score
def history_plot6(history):

    f12 = plt.figure(figsize=(12, 8))
    plt.plot(history.history['accuracy'], label="Train loss")
    plt.plot(history.history['val_accuracy'], label="Test loss")
    plt.legend()


def plot_nn_model(model):
    plot_model(model, show_shapes=True)
    
models_results = np.zeros(4)

# %%
models_results[-1] = neural_net_results6(test66,heart_df['HeartDisease'])
# Out:
# Epoch 1/70
# 65/65 [==============================] - 1s 8ms/step - loss: 0.6471 - accuracy: 0.6262 - val_loss: 0.5814 - val_accuracy: 0.6775
# Epoch 2/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.6026 - accuracy: 0.6729 - val_loss: 0.5755 - val_accuracy: 0.6667
# Epoch 3/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.6076 - accuracy: 0.6869 - val_loss: 0.5653 - val_accuracy: 0.6812
# Epoch 4/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.5923 - accuracy: 0.6963 - val_loss: 0.5582 - val_accuracy: 0.6884
# Epoch 5/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.5869 - accuracy: 0.6994 - val_loss: 0.5528 - val_accuracy: 0.6957
# Epoch 6/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5746 - accuracy: 0.7150 - val_loss: 0.5502 - val_accuracy: 0.6884
# Epoch 7/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5837 - accuracy: 0.7025 - val_loss: 0.5494 - val_accuracy: 0.6957
# Epoch 8/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.5868 - accuracy: 0.7072 - val_loss: 0.5478 - val_accuracy: 0.6920
# Epoch 9/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5875 - accuracy: 0.7196 - val_loss: 0.5501 - val_accuracy: 0.6848
# Epoch 10/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5816 - accuracy: 0.7009 - val_loss: 0.5478 - val_accuracy: 0.6848
# Epoch 11/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5651 - accuracy: 0.7181 - val_loss: 0.5462 - val_accuracy: 0.6775
# Epoch 12/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5782 - accuracy: 0.7103 - val_loss: 0.5418 - val_accuracy: 0.7029
# Epoch 13/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5769 - accuracy: 0.7259 - val_loss: 0.5468 - val_accuracy: 0.6957
# Epoch 14/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5557 - accuracy: 0.7352 - val_loss: 0.5487 - val_accuracy: 0.6920
# Epoch 15/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5766 - accuracy: 0.7181 - val_loss: 0.5446 - val_accuracy: 0.7101
# Epoch 16/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5643 - accuracy: 0.7290 - val_loss: 0.5474 - val_accuracy: 0.7174
# Epoch 17/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5677 - accuracy: 0.7118 - val_loss: 0.5476 - val_accuracy: 0.7101
# Epoch 18/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5720 - accuracy: 0.7290 - val_loss: 0.5495 - val_accuracy: 0.7138
# Epoch 19/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5747 - accuracy: 0.7118 - val_loss: 0.5465 - val_accuracy: 0.7101
# Epoch 20/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5684 - accuracy: 0.7274 - val_loss: 0.5513 - val_accuracy: 0.7029
# Epoch 21/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5776 - accuracy: 0.7040 - val_loss: 0.5524 - val_accuracy: 0.7101
# Epoch 22/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5691 - accuracy: 0.7243 - val_loss: 0.5519 - val_accuracy: 0.7065
# Epoch 23/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5713 - accuracy: 0.7212 - val_loss: 0.5474 - val_accuracy: 0.7138
# Epoch 24/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5593 - accuracy: 0.7321 - val_loss: 0.5455 - val_accuracy: 0.7138
# Epoch 25/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5634 - accuracy: 0.7305 - val_loss: 0.5456 - val_accuracy: 0.7246
# Epoch 26/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5663 - accuracy: 0.7134 - val_loss: 0.5492 - val_accuracy: 0.7138
# Epoch 27/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5516 - accuracy: 0.7305 - val_loss: 0.5458 - val_accuracy: 0.7246
# Epoch 28/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5769 - accuracy: 0.7072 - val_loss: 0.5423 - val_accuracy: 0.7355
# Epoch 29/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5591 - accuracy: 0.7305 - val_loss: 0.5475 - val_accuracy: 0.7101
# Epoch 30/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5614 - accuracy: 0.7274 - val_loss: 0.5500 - val_accuracy: 0.7174
# Epoch 31/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5571 - accuracy: 0.7383 - val_loss: 0.5476 - val_accuracy: 0.7174
# Epoch 32/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5560 - accuracy: 0.7321 - val_loss: 0.5525 - val_accuracy: 0.7210
# Epoch 33/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5599 - accuracy: 0.7305 - val_loss: 0.5479 - val_accuracy: 0.7138
# Epoch 34/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5611 - accuracy: 0.7305 - val_loss: 0.5479 - val_accuracy: 0.7138
# Epoch 35/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.5610 - accuracy: 0.7259 - val_loss: 0.5498 - val_accuracy: 0.7101
# Epoch 36/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5462 - accuracy: 0.7243 - val_loss: 0.5503 - val_accuracy: 0.7174
# Epoch 37/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5534 - accuracy: 0.7274 - val_loss: 0.5504 - val_accuracy: 0.7174
# Epoch 38/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5596 - accuracy: 0.7243 - val_loss: 0.5500 - val_accuracy: 0.7210
# Epoch 39/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5693 - accuracy: 0.7181 - val_loss: 0.5518 - val_accuracy: 0.7355
# Epoch 40/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.5516 - accuracy: 0.7352 - val_loss: 0.5490 - val_accuracy: 0.7355
# Epoch 41/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5506 - accuracy: 0.7274 - val_loss: 0.5521 - val_accuracy: 0.7174
# Epoch 42/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.5406 - accuracy: 0.7414 - val_loss: 0.5470 - val_accuracy: 0.7138
# Epoch 43/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5614 - accuracy: 0.7259 - val_loss: 0.5488 - val_accuracy: 0.7210
# Epoch 44/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5642 - accuracy: 0.7336 - val_loss: 0.5507 - val_accuracy: 0.7210
# Epoch 45/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5428 - accuracy: 0.7383 - val_loss: 0.5523 - val_accuracy: 0.7210
# Epoch 46/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5599 - accuracy: 0.7274 - val_loss: 0.5513 - val_accuracy: 0.7283
# Epoch 47/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.5515 - accuracy: 0.7368 - val_loss: 0.5501 - val_accuracy: 0.7138
# Epoch 48/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5672 - accuracy: 0.7087 - val_loss: 0.5498 - val_accuracy: 0.7101
# Epoch 49/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5527 - accuracy: 0.7259 - val_loss: 0.5452 - val_accuracy: 0.7174
# Epoch 50/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5498 - accuracy: 0.7383 - val_loss: 0.5473 - val_accuracy: 0.7138
# Epoch 51/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5531 - accuracy: 0.7290 - val_loss: 0.5532 - val_accuracy: 0.7065
# Epoch 52/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5440 - accuracy: 0.7227 - val_loss: 0.5510 - val_accuracy: 0.7101
# Epoch 53/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5452 - accuracy: 0.7259 - val_loss: 0.5514 - val_accuracy: 0.7029
# Epoch 54/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5470 - accuracy: 0.7336 - val_loss: 0.5481 - val_accuracy: 0.7138
# Epoch 55/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5445 - accuracy: 0.7445 - val_loss: 0.5502 - val_accuracy: 0.7029
# Epoch 56/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.5514 - accuracy: 0.7305 - val_loss: 0.5492 - val_accuracy: 0.7174
# Epoch 57/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5392 - accuracy: 0.7492 - val_loss: 0.5530 - val_accuracy: 0.7101
# Epoch 58/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5479 - accuracy: 0.7352 - val_loss: 0.5528 - val_accuracy: 0.7174
# Epoch 59/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5551 - accuracy: 0.7399 - val_loss: 0.5561 - val_accuracy: 0.7210
# Epoch 60/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.5402 - accuracy: 0.7243 - val_loss: 0.5590 - val_accuracy: 0.7174
# Epoch 61/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5522 - accuracy: 0.7445 - val_loss: 0.5572 - val_accuracy: 0.7138
# Epoch 62/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5421 - accuracy: 0.7305 - val_loss: 0.5567 - val_accuracy: 0.7210
# Epoch 63/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5456 - accuracy: 0.7274 - val_loss: 0.5522 - val_accuracy: 0.7029
# Epoch 64/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5420 - accuracy: 0.7430 - val_loss: 0.5590 - val_accuracy: 0.7101
# Epoch 65/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5474 - accuracy: 0.7368 - val_loss: 0.5589 - val_accuracy: 0.7029
# Epoch 66/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5448 - accuracy: 0.7352 - val_loss: 0.5579 - val_accuracy: 0.7174
# Epoch 67/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.5660 - accuracy: 0.7274 - val_loss: 0.5613 - val_accuracy: 0.7138
# Epoch 68/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5444 - accuracy: 0.7383 - val_loss: 0.5599 - val_accuracy: 0.7065
# Epoch 69/70
# 65/65 [==============================] - 0s 3ms/step - loss: 0.5596 - accuracy: 0.7243 - val_loss: 0.5571 - val_accuracy: 0.7101
# Epoch 70/70
# 65/65 [==============================] - 0s 4ms/step - loss: 0.5592 - accuracy: 0.7212 - val_loss: 0.5581 - val_accuracy: 0.7065
# Neural Network score    ========>>> 0.707
